# %%
# %run ../src/pipeline.py --mode incremental
# Out:
# 2026-04-28 16:50:44,184 - INFO - 🚀 Starting Weather Pipeline in 'INCREMENTAL' mode.
# 2026-04-28 16:50:44,217 - INFO - STAGE 1: Data Ingestion
# 2026-04-28 16:50:44,230 - INFO - 📥 Fetching Zerdab historical from 2026-04-18 to 2026-04-27...
# 2026-04-28 16:50:44,698 - INFO - 🔮 Fetching Zerdab forecast (14 days)...
# 2026-04-28 16:50:45,056 - INFO - 📥 Fetching Quba historical from 2026-04-18 to 2026-04-27...
# 2026-04-28 16:50:45,218 - INFO - 🔮 Fetching Quba forecast (14 days)...
# 2026-04-28 16:50:45,316 - INFO - 📥 Fetching Lenkeran historical from 2026-04-18 to 2026-04-27...
# 2026-04-28 16:50:45,474 - INFO - 🔮 Fetching Lenkeran forecast (14 days)...
# 2026-04-28 16:50:45,574 - INFO - 📥 Fetching Baki historical from 2026-04-18 to 2026-04-27...
# 2026-04-28 16:50:45,709 - INFO - 🔮 Fetching Baki forecast (14 days)...
# 2026-04-28 16:50:45,806 - INFO - 📥 Fetching Saatli historical from 2026-04-18 to 2026-04-27...
# ...

# %%
import duckdb
import pandas as pd

# 1. Connect to your local database
conn = duckdb.connect('../data/weather_pipeline.duckdb')

# 2. Query the gold-standard analytics layer
query = "SELECT * FROM analytics.weather_features"
df_ml = conn.execute(query).df()

# 3. Always close the connection when done fetching
conn.close()

# Let's see the data ready for modeling!
df_ml.head(50)
# Out:
#         city       date  temperature_2m_mean  et0_fao_evapotranspiration_sum  \
# 0       Baki 2026-04-18            13.668750                        2.861732
# 1       Baki 2026-04-19            15.177083                        3.267373
# 2       Baki 2026-04-20            13.847917                        2.064010
# 3       Baki 2026-04-21            10.787499                        1.553613
# 4       Baki 2026-04-22            13.112499                        3.127617
# 5       Baki 2026-04-23            12.887501                        1.882021
# 6       Baki 2026-04-24            12.620833                        3.192160
# 7       Baki 2026-04-25            12.772916                        2.846231
# 8       Baki 2026-04-26            12.181249                        2.825946
# 9       Baki 2026-04-27            14.366668                        3.629107
# 10      Baki 2026-04-28            12.858418                        4.854087
# ...
